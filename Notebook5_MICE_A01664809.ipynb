# %% [markdown]
# <a href="https://colab.research.google.com/github/YaelLopezS/Notebooks-Inteligencia-Artificial-2/blob/main/Notebook5_MICE_A01664809.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Missing values
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data = titanic[['age', 'fare', 'pclass', 'sex']]
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#     age     fare  pclass  sex_male
# 0  22.0   7.2500       3      True
# 1  38.0  71.2833       1     False
# 2  26.0   7.9250       3     False
# 3  35.0  53.1000       1     False
# 4  35.0   8.0500       3      True

# %%
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# %%
print("Datos originales")
print(data.head())
print("\nDatos imputados")
print(data_imputed.head())
# Out:
# Datos originales
#     age     fare  pclass  sex_male
# 0  22.0   7.2500       3      True
# 1  38.0  71.2833       1     False
# 2  26.0   7.9250       3     False
# 3  35.0  53.1000       1     False
# 4  35.0   8.0500       3      True
#
# Datos imputados
#     age     fare  pclass  sex_male
# 0  22.0   7.2500     3.0       1.0
# 1  38.0  71.2833     1.0       0.0
# 2  26.0   7.9250     3.0       0.0
# 3  35.0  53.1000     1.0       0.0
# 4  35.0   8.0500     3.0       1.0

# %% [markdown]
# **Exercise 1**
#
# Use MICE on the life-expectancy dataset kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/Life_Expectancy_Data.csv')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data = df.select_dtypes(include='number')
data.head()
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# %%
print("Valores faltantes en los datos originales:")
print(data.isnull().sum())
print("\nValores faltantes en los datos imputados:")
print(data_imputed.isnull().sum())
# Out:
# Valores faltantes en los datos originales:
# Year                                 0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64
#
# Valores faltantes en los datos imputados:
# Year                               0
# ...

# %% [markdown]
# **Exercise 2**
#
# Use MICE on the Planets (seaborn) dataset to fill in missing values.

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
data = planets[['orbital_period', 'mass', 'distance', 'year']]
data.head()
# Out:
#    orbital_period   mass  distance  year
# 0         269.300   7.10     77.40  2006
# 1         874.774   2.21     56.95  2008
# 2         763.000   2.60     19.84  2011
# 3         326.030  19.40    110.62  2007
# 4         516.220  10.50    119.47  2009

# %%
imputer = IterativeImputer(max_iter=10, random_state=0)

# %%
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)

# %%
print("Datos originales")
print(data.isnull().sum())
print("\nDatos imputados")
print(data_imputed.isnull().sum())
# Out:
# Datos originales
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64
#
# Datos imputados
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64
